# %%
from random import sample

# %%
import pandas as pd

# %%
from matplotlib.cm import get_cmap

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
data_x1 = range(1, 100, 5)
data_y1 = range(0, 20)
plt.plot(data_x1, data_y1)
plt.show()

# %%
data_x2 = sample(range(500), 5)
data_y2 = sample(range(100), 5)
plt.plot(data_x2, data_y2)
plt.show()

# %%
plt.plot(data_x1, data_y1, color='red', linestyle='dashed')
plt.figure()
plt.plot(data_x2, data_y2, color='green', linestyle='dotted', linewidth=5)
plt.show()

# %%
stations = pd.read_csv(open('bus_stops.csv', 'r', encoding="cp1251"), sep=";")
pavilion_count = stations.groupby(['Pavilion']).size()
plt.pie(pavilion_count, labels=pavilion_count.index, autopct='%.2f')
plt.title('Остановки')
plt.legend()
plt.show()

# %%
admarea_count = stations.groupby(['AdmArea']).size()

# %%
admarea_count
# Out:
# AdmArea
# AdmArea                                      11
# Восточный административный округ           1406
# Западный административный округ            1239
# Зеленоградский административный округ       240
# Новомосковский административный округ       555
# Северный административный округ            1047
# Северо-Восточный административный округ    1142
# Северо-Западный административный округ      800
# Троицкий административный округ             401
# Центральный административный округ         1020
# Юго-Восточный административный округ       1173
# Юго-Западный административный округ        1065
# Южный административный округ               1379
# dtype: int64

# %%
labels = ['ВАО', 'ЗАО', 'Зел', 'Нов', 'САО', 'СВАО', 'СЗАО', 'Тро', 'ЦАО', 'ЮВАО', 'ЮЗАО', 'ЮАО']
cmap = get_cmap('tab20')
colors = [cmap(i) for i in range(len(labels))]
plt.bar(labels, admarea_count, color=colors)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-7631831e5152> in <module>
#       2 cmap = get_cmap('tab20')
#       3 colors = [cmap(i) for i in range(len(labels))]
# ----> 4 plt.bar(labels, admarea_count, color=colors)
#       5 plt.show()
#
# ~/Desktop/projects/DataTrack/myenv/lib/python3.7/site-packages/matplotlib/pyplot.py in bar(x, height, width, bottom, align, data, **kwargs)
#    2438     return gca().bar(
#    2439         x, height, width=width, bottom=bottom, align=align,
# -> 2440         **({"data": data} if data is not None else {}), **kwargs)
#    2441
#    2442
#
# ~/Desktop/projects/DataTrack/myenv/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1599     def inner(ax, *args, data=None, **kwargs):
#    1600         if data is None:
# -> 1601             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1602
#    1603         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/Desktop/projects/DataTrack/myenv/lib/python3.7/site-packages/matplotlib/axes/_axes.py in bar(self, x, height, width, bottom, align, **kwargs)
#    2373         x, height, width, y, linewidth = np.broadcast_arrays(
#    2374             # Make args iterable too.
# -> 2375             np.atleast_1d(x), height, width, y, linewidth)
#    2376
#    2377         # Now that units have been converted, set the tick locations.
#
# <__array_function__ internals> in broadcast_arrays(*args, **kwargs)
#
# ~/Desktop/projects/DataTrack/myenv/lib/python3.7/site-packages/numpy/lib/stride_tricks.py in broadcast_arrays(*args, **kwargs)
#     262     args = [np.array(_m, copy=False, subok=subok) for _m in args]
#     263
# --> 264     shape = _broadcast_shape(*args)
#     265
#     266     if all(array.shape == shape for array in args):
#
# ~/Desktop/projects/DataTrack/myenv/lib/python3.7/site-packages/numpy/lib/stride_tricks.py in _broadcast_shape(*args)
#     189     # use the old-iterator because np.nditer does not handle size 0 arrays
#     190     # consistently
# --> 191     b = np.broadcast(*args[:32])
#     192     # unfortunately, it cannot handle 32 or more arguments directly
#     193     for pos in range(32, len(args), 31):
#
# ValueError: shape mismatch: objects cannot be broadcast to a single shape
