# %%
import pandas as pd

# %%
pd.options.display.float_format = '{:.2f}'.format

# %%
export_2015=pd.read_excel('Russia-2015.xlsx', sheet_name='Partner')

# %%
export_2016=pd.read_excel('Russia-2016.xlsx', sheet_name='Partner')

# %%
export=pd.concat([export_2015, export_2016])

# %%
export.sample(10)
# Out:
#           Reporter Name                Partner Name  Year Trade Flow  \
# 196  Russian Federation                   Swaziland  2016     Export
# 17   Russian Federation                     Bonaire  2016     Export
# 24   Russian Federation      Bosnia and Herzegovina  2015     Export
# 121  Russian Federation                   Sri Lanka  2016     Export
# 174  Russian Federation                       Qatar  2016     Export
# 38   Russian Federation                       China  2015     Export
# 69   Russian Federation  Ethiopia(excludes Eritrea)  2016     Export
# 133  Russian Federation            Marshall Islands  2016     Export
# 138  Russian Federation                  Mauritania  2015     Export
# 86   Russian Federation                   Greenland  2016     Export
#
#      No Of exported HS6 digit Products  Export Share in Total Products (%)  \
# 196                                NaN                                 NaN
# 17                                 1.0                                0.02
# 24                               186.0                                4.30
# 121                               79.0                                1.82
# 174                              115.0                                2.64
# 38                              1374.0                               31.73
# 69                               140.0                                3.22
# 133                               37.0                                0.85
# 138                               13.0                                0.30
# 86                                 1.0                                0.02
#
#      Export (US$ Thousand)  Export Partner Share (%)
# 196                    NaN                       NaN
# 17                45718.39                      0.02
# 24               177867.37                      0.05
# 121               80702.25                      0.03
# 174               24458.67                      0.01
# 38             28334954.57                      8.24
# 69               194487.81                      0.07
# 133                 466.20                      0.00
# 138               17473.51                      0.01
# 86                   12.06                      0.00

# %%
exclude = ['Europe & Central Asia', 'East Asia & Pacific', ' World', 'Unspecified', 'Middle East & North Africa']
export_filtered = export[-export['Partner Name'].isin(exclude)]

# %%
export_pivot = export_filtered.pivot_table(index=['Year', 'Partner Name'], 
                values='Export (US$ Thousand)', aggfunc='sum')\
            .sort_values(
                ['Year', 'Export (US$ Thousand)'],
                ascending=[True, False]
            )

# %%
export_pivot[export_pivot.index.get_level_values('Year') == 2015]
# Out:
#                                      Export (US$ Thousand)
# Year Partner Name
# 2015 Netherlands                               40198496.43
#      China                                     28334954.57
#      Italy                                     16204284.05
#      Germany                                   15906242.25
#      Japan                                     14426352.10
# ...                                                    ...
#      Turks and Caicos Isl.                            0.00
#      Tuvalu                                           0.00
#      United States Minor Outlying I                   0.00
#      Vanuatu                                          0.00
#      Wallis and Futura Isl.                           0.00
#
# [226 rows x 1 columns]
